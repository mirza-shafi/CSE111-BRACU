# %%
#task-01
class Patient:
    def __init__(self,name,age,weight,height):
        self.name = name
        self.age = age
        self.weight = weight
        self.height = height
        self.bmi = weight/(height/100)**2
    def details(self):
        print('Name:',self.name,'\nAge:',self.age,'\nWeight:',self.weight,'kg','\nHeight:',self.height,'cm','\nMBI:',self.bmi)
p1 = Patient('A',55,63.0,158.0)
p1.details()
print('========================================')
p2 = Patient('B',53,61.0,149.0)
p2.details()
# Out:
# Name: A
# Age: 55
# Weight: 63.0 kg
# Height: 158.0 cm
# MBI: 25.236340330075304
# ========================================
# Name: B
# Age: 53
# Weight: 61.0 kg
# Height: 149.0 cm
# MBI: 27.476239809017613

# %%
#task-02
class Shape:
    def __init__(self,*n):
        if n[0] == "Triangle":
            self.a = 1/2*n[2]*n[1]
        elif n[0]=='Square':
            self.a = n[1]*n[2]
        elif n[0]=='Rhombus':
            self.a = (n[1]*n[2])/2
        elif n[0]=='Rectangle':
            self.a = n[1]*n[2]
        elif n[0]=='Trapezium':
            self.a = 'Shape unknown'
    def area(self):
        print('Area:',self.a)


triangle = Shape("Triangle",10,25) 
triangle.area() 
print("==========================") 
square = Shape("Square",10,10) 
square.area() 
print("==========================") 
rhombus = Shape("Rhombus",18,25) 
rhombus.area() 
print("==========================") 
rectangle = Shape("Rectangle",15,30) 
rectangle.area() 
print("==========================") 
trapezium = Shape("Trapezium",15,30) 
trapezium.area()
# Out:
# Area: 125.0
# ==========================
# Area: 100
# ==========================
# Area: 225.0
# ==========================
# Area: 450
# ==========================
# Area: Shape unknown

# %%
#task-03
class Calculator:
    def __init__(self):
        print('Calculator is ready!')
    def calculate(self,n1,n2,s):
       self.n1 = n1
       self.n2 = n2
       self.s = s
       if s=='+':
           return n1+n2
       elif s=='-':
           return n1-n2
       elif s=='*':
           return n1*n2
       elif s=='/':
           return n1/n2
    def showCalculation(self):
        print(self.n1,self.s,self.n2,'=',val)
        

c1 = Calculator() 
print("==================") 
val = c1.calculate(10, 20, '+') 
print("Returned value:", val) 
c1.showCalculation() 
print("==================") 
val = c1.calculate(val, 10, '-') 
print("Returned value:", val) 
c1.showCalculation() 
print("==================") 
val = c1.calculate(val, 5, '*') 
print("Returned value:", val) 
c1.showCalculation() 
print("==================") 
val = c1.calculate(val, 16, '/') 
print("Returned value:", val) 
c1.showCalculation()
# Out:
# Calculator is ready!
# ==================
# Returned value: 30
# 10 + 20 = 30
# ==================
# Returned value: 20
# 30 - 10 = 20
# ==================
# Returned value: 100
# 20 * 5 = 100
# ==================
# Returned value: 6.25
# 100 / 16 = 6.25

# %%
#another solve
class Calculator:
    def __init__(self):
        print('Calculator is ready')
    def calculate(self,m,n,s):
        self.m = m
        self.n = n
        self.s = s
        if self.s == '+':
            self.obj = self.m+self.n
            return self.obj
        elif self.s == '-':
            self.obj = self.m-self.n
            return self.obj
        elif self.s == '*':
            self.obj = self.m*self.n
            return self.obj
        elif self.s == '/':
            self.obj = self.m/self.n
            return self.obj
    def showCalculation(self):
        print(self.m,self.s,self.n,'=',self.obj)
c1 = Calculator() 
print("==================") 
val = c1.calculate(10, 20, '+') 
print("Returned value:", val) 
c1.showCalculation() 
print("==================") 
val = c1.calculate(val, 10, '-') 
print("Returned value:", val) 
c1.showCalculation() 
print("==================") 
val = c1.calculate(val, 5, '*') 
print("Returned value:", val) 
c1.showCalculation() 
print("==================") 
val = c1.calculate(val, 16, '/') 
print("Returned value:", val) 
c1.showCalculation()
# Out:
# Calculator is ready
# ==================
# Returned value: 30
# 10 + 20 = 30
# ==================
# Returned value: 20
# 30 - 10 = 20
# ==================
# Returned value: 100
# 20 * 5 = 100
# ==================
# Returned value: 6.25
# 100 / 16 = 6.25

# %%
#task-04
class Programmer:
    def __init__(self,name,l,num):
        self.name = name
        self.l = l
        self.num = num
        self.con = 'Horray! A new programmer is born'
    def addExp(self,num):
        self.con = 'Updating experience of Jon Snow'
        self.num = self.num+num
    def printDetails(self):
        print(self.con)
        print('Name:',self.name)
        print('Language:',self.l)
        print('Experience:',self.num,'years')
    

p1 = Programmer("Ethen Hunt", "Java", 10) 
p1.printDetails() 
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7) 
p2.printDetails() 
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4) 
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10 years
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7 years
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4 years
# Updating experience of Jon Snow
# Name: Jon Snow
# Language: Python
# Experience: 9 years

# %%
#task-05 another solve
class UberEats:
    def __init__(self,name,number,location):
        self.name = name
        self.number = number
        self.location  = location
        print(self.name,'welcome to UberEats!')
        self.order  = {}
    def add_items(self,m,n,mp,np):
        self.m = m
        self.n = n
        self.mp  = mp
        self.np = np
        self.order[m] = mp
        self.order[n] = np
        self.total = mp+np
    def print_order_detail(self):
        obj = f"Name: {self.name} Phone: {self.number} Location:{self.location} \nOrders: {self.order} \nTotal price amount: {self.total}"
        return obj


order1 = UberEats("Shakib", "01719658xxx", "Mohakhali") 
print("=========================") 
order1.add_items("Burger", "Coca Cola", 220, 50) 
print("=========================") 
print(order1.print_order_detail()) 
print("=========================")
order2 = UberEats ("Siam", "01719659xxx", "Uttara") 
print("=========================") 
order2.add_items("Pineapple", "Dairy Milk", 80, 70) 
print("=========================") 
print(order2.print_order_detail())

# %%
#task-05
class UberEats:
    def __init__(self,name,num,lo):
        self.name = name
        self.num = num
        self.lo = lo
        print(f'{self.name}, welcome to UberEasts')
    def add_items(self,n1,n2,num1,num2):
        self.n1 = n1
        self.n2 = n2
        self.num1 = num1
        self.num2 = num2
        self.dic = {self.n1:self.num1,self.n2:self.num2}
    def print_order_detail(self):
        return f'User details: Name:{self.name},Phone: \n{self.num},Address:{self.lo} \nOrder:{self.dic} \nTotal Paid Amount: {self.num1+self.num2}'

order1 = UberEats("Shakib", "01719658xxx", "Mohakhali") 
print("=========================") 
order1.add_items("Burger", "Coca Cola", 220, 50) 
print("=========================") 
print(order1.print_order_detail()) 
print("=========================")
order2 = UberEats ("Siam", "01719659xxx", "Uttara") 
print("=========================") 
order2.add_items("Pineapple", "Dairy Milk", 80, 70) 
print("=========================") 
print(order2.print_order_detail())
# Out:
# Shakib, welcome to UberEasts
# =========================
# =========================
# User details: Name:Shakib,Phone:
# 01719658xxx,Address:Mohakhali
# Order:{'Burger': 220, 'Coca Cola': 50}
# Total Paid Amount: 270
# =========================
# Siam, welcome to UberEasts
# =========================
# =========================
# User details: Name:Siam,Phone:
# 01719659xxx,Address:Uttara
# Order:{'Pineapple': 80, 'Dairy Milk': 70}
# Total Paid Amount: 150

# %%
#task-06
class Customer:
    def __init__(self,name):
        self.name = name
    def greet(self,n = ''): 
        self.n = n
        print(f'Hello {self.n}!')
    def purchase(self,*n):
        self.l = len(n)
        print(f'{self.name},you purchased {self.l}item(s)')
        for i in n:
            print(i)

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice") 
print("-----------------------------")
customer_2 = Customer("David") 
customer_2.greet("David") 
customer_2.purchase("orange juice")
# Out:
# Hello !
# Sam,you purchased 3item(s)
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David,you purchased 1item(s)
# orange juice

# %%
#task-07
class Cat:
    def __init__(self,color = 'White',n = 'sitting'):
        self.color =  color
        self.n = n
    def changeColor(self,co):
        self.color = co
    def printCat(self):
        print(f'{self.color} cat is {self.n}')
c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping") 
c4 = Cat("Red", "purring") 
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat() 
c1.changeColor("Blue") 
c3.changeColor("Purple") 
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#task-08
class Student:
    def __init__(self,name,num,dp = 'CSE'):
        self.name = name
        self.num = num
        self.dp = dp
    def dailyEffort(self,h):
            self.h = h
            if self.h<=2:
                self.s = 'Suggestion: Should give more effort!'
            elif self.h<=4:
                self.s = 'Suggestion: Keep up the good work!'
            else:
                self.s = 'Suggestion: Excellent! Now motivate others.'
    def printDetails(self):
        print(f'Name: {self.name} \nID: {self.num} \nDepartment:{self.dp} \nDaily Effort: {self.h} hour(s) \nSuggestion: {self.s}')
harry = Student('Harry Potter', 123) 
harry.dailyEffort(3)
harry.printDetails() 
print('========================') 
john = Student("John Wick", 456, "BBA") 
john.dailyEffort(2)
john.printDetails() 
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja") 
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department:CSE
# Daily Effort: 3 hour(s)
# Suggestion: Suggestion: Keep up the good work!
# ========================
# Name: John Wick
# ID: 456
# Department:BBA
# Daily Effort: 2 hour(s)
# Suggestion: Suggestion: Should give more effort!
# ========================
# Name: Naruto Uzumaki
# ID: 777
# Department:Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Suggestion: Excellent! Now motivate others.

# %%
#task=09
class Batsman:
    def __init__(self,*bats):
        if len(bats)==2:
            self.name = 'New Batsman'
            self.run = bats[0]
            self.ball = bats[1]
        elif len(bats)==3:
            self.name = bats[0]
            self.run = bats[1]
            self.ball = bats[2]
    def printCareerStatistics(self):
        print(f'Name: {self.name}')
        print(f'Runs Scord: {self.run}, Balls Faced: {self.ball}')
    def battingStrikeRate(self):
        return self.run/self.ball *100
    def setName(self,name):
        self.name = name

b1 = Batsman(6101, 7380) 
b1.printCareerStatistics() 
print("============================") 
b2 = Batsman("Liton Das", 678, 773) 
b2.printCareerStatistics() 
print("----------------------------") 
print(b2.battingStrikeRate()) 
print("============================") 
b1.setName("Shakib Al Hasan") 
b1.printCareerStatistics() 
print("----------------------------") 
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scord: 6101, Balls Faced: 7380
# ============================
# Name: Liton Das
# Runs Scord: 678, Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ============================
# Name: Shakib Al Hasan
# Runs Scord: 6101, Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#task-10 another solve
class Author:
    def __init__(self,*n):
        self.book  = []
        if len(n)==0:
            self.name = 'Default'
        elif len(n)==1:
            self.name = n[0]
        elif len(n)==3:
            self.name = n[0]
            for i in range(1,len(n)):
                self.book.append(n[i])
    def addBooks(self,*book):
        self.book = book
    def changeName(self,na):
        self.name = na
    def printDetails(self):
        print('Author name:',self.name)
        print('------------')
        print('List of Books:')
        for i in self.book:
            print(i)
auth1 = Author('Humayun Ahmed') 
auth1.addBooks('Deyal', 'Megher Opor Bari') 
auth1.printDetails() 
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian') 
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain') 
auth3.printDetails()
# Out:
# Author name: Humayun Ahmed
# ------------
# List of Books:
# Deyal
# Megher Opor Bari
# ===================
# Default
# ===================
# Author name: Mario Puzo
# ------------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ===================
# Author name: Paolo Coelho
# ------------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#task-10
class Author:
    def __init__(self,name = 'Default',book1 = '',book2 = ''):
        self.name = name
        self.book1  = book1
        self.book2 = book2
        self.book = [self.book1,self.book2]
    def addBooks(self,*book):
        self.book  = book
    def printDetails(self):
        print(f'Author Name: {self.name}')
        print('--------')
        print(f'List of Books:')
        for i in self.book:
            print(i)
    def changeName(self,name):
        self.name = name
auth1 = Author('Humayun Ahmed') 
auth1.addBooks('Deyal', 'Megher Opor Bari') 
auth1.printDetails() 
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian') 
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain') 
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ===================
# Default
# ===================
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ===================
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#another solve
class Author:
    def __init__(self,name=None,book1=None,book2=None):
        
        if name==None:
            self.name="Default"
        else:
            self.name=name
        if book1==None and book2==None:
            self.books=[]
        else:
            self.books=[book1,book2]
    def addBooks(self,*items):
        for i in items:
            (self.books).append(i)
    def changeName(self,x):
        self.name=x
    def printDetails(self):
        print(f"Author Name : {self.name}\n--------\nList of Books:")
        for i in self.books:
            print(i)
auth1 = Author('Humayun Ahmed') 
auth1.addBooks('Deyal', 'Megher Opor Bari') 
auth1.printDetails() 
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian') 
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain') 
auth3.printDetails()
# Out:
# Author Name : Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ===================
# Default
# ===================
# Author Name : Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ===================
# Author Name : Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#11
class TaxiLagbe:
    def __init__(self,taxinumber,co):
        self.taxinumber=taxinumber
        self.co=co
        self.passengerlist=[]
        self.totalpassengers=0
        self.fare=0     
    def addPassenger(self,*pinf):
        if self.totalpassengers>=4:
            print("Taxi Full! No more passengers can be added.")
        else:
            for i in pinf:
                x=i.split("_")
                self.totalpassengers+=1
                self.fare+=int(x[1])
                (self.passengerlist).append(x[0])
                print(f"Dear {x[0]}! Welcome to TaxiLagbe.")
                
    def printDetails(self):
        print(f"Trip info for Taxi number:{self.taxinumber}\nThis taxi can cover only {self.co} area.\nTotal passengers:{self.totalpassengers}\nPassenger List:")
        for i in self.passengerlist:
            print(i,end=",")
        print("\nTotal collected fare:",self.fare)
taxi1 = TaxiLagbe('1010-01', 'Dhaka') 
print('-------------------------------') 
taxi1.addPassenger('Walker_100', 'Wood_200') 
taxi1.addPassenger('Matt_100') 
taxi1.addPassenger('Wilson_105') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi1.addPassenger('Karen_200') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna') 
taxi2.addPassenger('Ronald_115') 
taxi2.addPassenger('Parker_215') 
print('-------------------------------') 
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger List:
# Walker,Wood,Matt,Wilson,
# Total collected fare: 505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number:1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger List:
# Walker,Wood,Matt,Wilson,
# Total collected fare: 505
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:1010-02
# This taxi can cover only Khulna area.
# Total passengers:2
# Passenger List:
# Ronald,Parker,
# Total collected fare: 330

# %%
class TaxiLagbe:
    def __init__(self,taxinumber=None,coveredarea=None):
        self.taxinumber=taxinumber
        self.coveredarea=coveredarea
        self.passengerlist=[]
        self.totalpassengers=0
        self.fare=0     
    def addPassenger(self,*passengerinf):
        if self.totalpassengers>=4:
            print("Taxi Full! No more passengers can be added.")
        else:
            for i in passengerinf:
                x=i.split("_")
                self.totalpassengers+=1
                self.fare+=int(x[1])
                (self.passengerlist).append(x[0])
                print(f"Dear {x[0]}! Welcome to TaxiLagbe.")
                
    def printDetails(self):
        print(f"Trip info for Taxi number:{self.taxinumber}\nThis taxi can cover only {self.coveredarea} area.\nTotal passengers:{self.totalpassengers}\nPassenger List:")
        for i in self.passengerlist:
            print(i,end=",")
        print("\nTotal collected fare:",self.fare)
    
        

 

taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200')
taxi1.addPassenger('Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115')
taxi2.addPassenger('Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger List:
# Walker,Wood,Matt,Wilson,
# Total collected fare: 505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number:1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger List:
# Walker,Wood,Matt,Wilson,
# Total collected fare: 505
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:1010-02
# This taxi can cover only Khulna area.
# Total passengers:2
# Passenger List:
# Ronald,Parker,
# Total collected fare: 330

# %%
#another solve 11
class TaxiLagbe:
    def __init__(self,number,location):
        self.number = number
        self.location = location
        self.p = []
        self.total = 0
    def addPassenger(self,*x):
        if len(self.p)>=4:
            print("Taxi Full! No more passengers can be added.")
        else:
            for i in x:
               self.name,self.taka = i.split('_')
               self.p.append(self.name)
               self.total+=int(self.taka)
               print(f"Dear {self.name}! Welcome to TaxiLagbe.")
               
               
    def printDetails(self):
        print(f"Trip info for Taxi number: {self.number}")
        print(f"This taxi can cover only {self.location} area.")
        print(f"Total passengers:{len(self.p)}")
        print('Passenger lists:')
        for i in self.p:
            print(i,end = ', ')
        print(f"\nTotal collected fare: {self.total}")
        
taxi1 = TaxiLagbe('1010-01', 'Dhaka') 
print('-------------------------------') 
taxi1.addPassenger('Walker_100', 'Wood_200') 
taxi1.addPassenger('Matt_100') 
taxi1.addPassenger('Wilson_105') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi1.addPassenger('Karen_200') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna') 
taxi2.addPassenger('Ronald_115') 
taxi2.addPassenger('Parker_215') 
print('-------------------------------') 
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger lists:
# Walker, Wood, Matt, Wilson,
# Total collected fare: 505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger lists:
# Walker, Wood, Matt, Wilson,
# Total collected fare: 505
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers:2
# Passenger lists:
# Ronald, Parker,
# Total collected fare: 330

# %%
#task-12
class Account:
    def __init__(self,name="Default",balance=0.0):
            self.name=name
            self.balance=balance
    def details(self):
        return(f"{self.name}\n{self.balance}")
    def withdraw(self,wa):
        if (self.balance-wa) <= 3070:
            print('Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.')
        else:
            nb = self.balance-wa
            print(f'Withdraw successful! New balance is: {nb}')
            

a1 = Account() 
print(a1.details()) 
print("------------------------") 
a1.name = "Oliver" 
a1.balance = 10000.0 
print(a1.details()) 
print("------------------------") 
a2 = Account("Liam") 
print(a2.details()) 
print("------------------------") 
a3 = Account("Noah",400) 
print(a3.details()) 
print("------------------------") 
a1.withdraw(6930) 
print("------------------------") 
a2.withdraw(600) 
print("------------------------") 
a1.withdraw(6929)
# Out:
# Default
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#task-13
class StudentDatabase:
    def __init__(self, name, id):
        self.name = name
        self.id = id
        self.grades = {}

    def calculateGPA(self, gradeSheet, sem):
        courses = []
        gp_list = []
        for item in gradeSheet:
            course, gp = item.split(": ")
            gp = float(gp)
            courses.append(course)
            gp_list.append(gp)
        

        gpa = sum(gp_list) / len(gp_list)
        gpa = round(gpa, 2)
        print(sum(gp_list))

        courses = tuple(courses)
        self.grades[sem] = {courses:gpa}

    def printDetails(self):
        print("Name: ", self.name)
        print("ID: ", self.id)
        
        for sem, res in self.grades.items():
            print(f"Courses taken in {sem}:")

            for courses in self.grades[sem]:
                for course in courses:
                    print(course)
                print(self.grades[sem][courses])
            



s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('------------------------------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('------------------------------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('------------------------------------------------------')
s2.printDetails()
# Out:
# 12.0
# 7.7
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ------------------------------------------------------
# Name:  Pietro
# ID:  10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# 4.0
# Courses taken in Summer2021:
# CSE250
# CSE330
# 3.85
# 11.4
# ------------------------------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ------------------------------------------------------
# Name:  Wanda
# ID:  10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# 3.8

# %%
#task-14
class Test3:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):
        x, y = 2, 3
        msg = [0]
        msg[0] = 3
        y = self.y + msg[0]
        self.methodB(msg, msg[0])
        x = self.y + msg[0]
        self.sum  = x + y + msg[0]
        print(x, y, self.sum)
    def methodB(self, mg2, mg1):
        x =0
        self.y = self.y + mg2[0]
        x = x + 33 + mg1
        self.sum = self.sum + x + self.y
        mg2[0] = self.y + mg1
        mg1 = mg1 + x + 2
        print(x, self.y, self.sum)
t3 = Test3()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 36 3 39
# 9 3 18
# 36 6 60
# 15 6 30
# 36 9 75
# 21 9 42

# %%
#task-15
class Test5:
    def __init__(self):
      self.sum, self.y = 0, 0
    def methodA(self):
      x =0
      z =0
      while (z < 5):
        self.y = self.y + self.sum
        x = self.y + 1
        print(x, self.y, self.sum)
        self.sum = self.sum + self.methodB(x, self.y)
        z += 1
    def methodB(self, m, n):
        x = 0
        sum = 0
        self.y = self.y + m
        x = n -4
        sum = sum + self.y
        print(x, self.y, sum)
        return self.sum
t5 = Test5()
t5.methodA()
# Out:
# 1 0 0
# -4 1 1
# 2 1 0
# -3 3 3
# 4 3 0
# -1 7 7
# 8 7 0
# 3 15 15
# 16 15 0
# 11 31 31

# %%
#task-16
class FinalT6A:
    def __init__(self, x, p):
       self.temp, self.sum, self.y = 4, 0, 1
       self.temp += 1
       self.y = self.temp - p
       self.sum = self.temp + x
       print(x, self.y, self.sum)
    def methodA(self):
       x =0
       y =0
       y = y + self.y
       x = self.y + 2 + self.temp
       self.sum = x + y + self.methodB(self.temp, y)
       print(x, y, self.sum)
    def methodB(self, temp, n):
       x =0
       temp += 1
       self.y = self.y + temp
       x = x +3 + n
       self.sum = self.sum + x + self.y
       print(x, self.y, self.sum)
       return self.sum

q1 = FinalT6A(2,1)
q1.methodA()
q1.methodA()
# Out:
# 2 4 7
# 7 10 24
# 11 4 39
# 13 16 68
# 17 10 95

# %%
#task-17
class Test5:
    def __init__(self):
      self.sum = 0
      self.y = 0
    def methodA(self):
      x=y=k=0
      msg = [5]
      while (k < 2):
        y += msg[0]
        x = y + self.methodB(msg, k)
        self.sum = x + y + msg[0]
        print(x ," " , y, " " , self.sum)
        k+=1
    def methodB(self, mg2, mg1):
        x =0
        self.y += mg2[0]
        x = x + 3 + mg1
        self.sum += x + self.y
        mg2[0] = self.y + mg1
        mg1 += x + 2
        print(x , " " ,self.y, " " , self.sum)
        return mg1
t1 = Test5()
t1.methodA()
t1.methodA()
t1.methodA()
# Out:
# 3   5   8
# 10   5   20
# 4   10   34
# 17   10   38
# 3   15   56
# 10   5   30
# 4   30   64
# 27   20   78
# 3   35   116
# 10   5   50
# 4   70   124
# 47   40   158

# %%
#task-18
class Test4:
    def __init__(self):
       self.sum, self.y = 0, 0
    def methodA(self):
       x, y = 0, 0
       msg = [0]
       msg[0] = 5
       y = y + self.methodB(msg[0])
       x = y + self.methodB(msg, msg[0])
       self.sum = x + y + msg[0]
       print(x, y, self.sum)
    def methodB(self, *args):
        if len(args) == 1:
          mg1 = args[0]
          x, y = 0, 0
          y = y + mg1
          x = x + 33 + mg1
          self.sum = self.sum + x + y
          self.y = mg1 + x + 2
          print(x, y, self.sum)
          return y
        else:
          mg2, mg1 = args
          x =0
          self.y = self.y + mg2[0]
          x = x + 33 + mg1
          self.sum = self.sum + x + self.y
          mg2[0] = self.y + mg1
          mg1 = mg1 + x + 2
          print(x, self.y, self.sum)
          return self.sum
t3 = Test4()
t3.methodA()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 38 5 43
# 38 50 131
# 136 5 196
# 38 5 239
# 38 50 327
# 332 5 392
# 38 5 435
# 38 50 523
# 528 5 588
# 38 5 631
# 38 50 719
# 724 5 784
